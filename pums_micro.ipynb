# %%
% matplotlib inline
import pandas as pd
import math
import matplotlib.pyplot as plt
import os
from datetime import datetime as dtdt

# %%
os.listdir('./metadata/')
# Out:
# ['ANC1P.txt', 'LANP.txt', 'PUMA.txt', 'POB.txt', 'POBP.txt']

# %%
with open('./metadata/LANP.txt', 'r') as f:
    lanp = f.readlines()
    LanpMap = dict([(l[:4], l[6:].strip()) for l in lanp])
    
with open('./metadata/POBP.txt', 'r') as f:
    pobp = f.readlines()
    PobpMap = dict([(l[:3], l[5:].strip()) for l in pobp])

with open('./metadata/ANC1P.txt', 'r') as f:
    ancp = f.readlines()
    AncpMap = dict([(l[:3], l[5:].strip()) for l in ancp])
    
LanpMapDf = pd.DataFrame(LanpMap, ['language']).transpose()
LanpMapDf.index.name = 'LANP'

PobpMapDf = pd.DataFrame(PobpMap, ['birthplace']).transpose()
PobpMapDf.index.name = 'POBP'

AncpMapDf = pd.DataFrame(AncpMap, ['ancestry']).transpose()
AncpMapDf.index.name = 'ANCP'

with open('./metadata/PUMA.txt', 'r') as f:
    puma = f.readlines()

PumaMapDf = pd.DataFrame([{'state': ln[:2], 'puma': ln[3:8], 'name': ln[9:].strip()} for ln in puma])[['state', 'puma', 'name']]

NyPumaMapDf = PumaMapDf[PumaMapDf.state=='36'].set_index('puma')[['name']]
CaPumaMapDf = PumaMapDf[PumaMapDf.state=='06'].set_index('puma')[['name']]

pumasNYC = NyPumaMapDf[NyPumaMapDf.name.str.startswith('NYC')].index
pumasLA = CaPumaMapDf[CaPumaMapDf.name.str.startswith('Los Angeles County')].index

# %%
print dtdt.now(), 'read file'
CaPums = pd.read_csv('data/csv_pca/psam_p06.csv')
print dtdt.now(), 'format columns'
CaPums.LANP = CaPums.LANP.fillna('bbbb').apply(lambda n: str(n)[:4])
CaPums.POBP = CaPums.POBP.apply(lambda n: '%03d' % n)
CaPums.ANC1P = CaPums.ANC1P.apply(lambda n: '%03d' % n)
CaPums.PUMA = CaPums.PUMA.apply(lambda n: '%05d' % n)
print dtdt.now(), 'done'

CaPums
# Out:
# 2021-08-12 18:47:53.955952 read file
# 2021-08-12 18:48:24.383988 format columns
# 2021-08-12 18:48:28.587865 done
#        RT       SERIALNO  DIVISION  SPORDER   PUMA  REGION  ST   ADJINC  \
# 0       P  2019GQ0000003         9        1  03704       4   6  1010145
# 1       P  2019GQ0000009         9        1  07322       4   6  1010145
# 2       P  2019GQ0000013         9        1  05904       4   6  1010145
# 3       P  2019GQ0000023         9        1  07107       4   6  1010145
# 4       P  2019GQ0000024         9        1  08900       4   6  1010145
# 5       P  2019GQ0000048         9        1  03729       4   6  1010145
# 6       P  2019GQ0000055         9        1  11105       4   6  1010145
# 7       P  2019GQ0000064         9        1  03703       4   6  1010145
# 8       P  2019GQ0000070         9        1  11104       4   6  1010145
# 9       P  2019GQ0000074         9        1  02901       4   6  1010145
# 10      P  2019GQ0000080         9        1  04102       4   6  1010145
# 11      P  2019GQ0000081         9        1  00102       4   6  1010145
# 12      P  2019GQ0000083         9        1  07301       4   6  1010145
# 13      P  2019GQ0000098         9        1  03718       4   6  1010145
# 14      P  2019GQ0000110         9        1  03744       4   6  1010145
# 15      P  2019GQ0000119         9        1  09903       4   6  1010145
# 16      P  2019GQ0000134         9        1  01500       4   6  1010145
# 17      P  2019GQ0000158         9        1  11103       4   6  1010145
# 18      P  2019GQ0000200         9        1  03749       4   6  1010145
# 19      P  2019GQ0000219         9        1  00103       4   6  1010145
# 20      P  2019GQ0000225         9        1  00101       4   6  1010145
# 21      P  2019GQ0000226         9        1  07310       4   6  1010145
# 22      P  2019GQ0000230         9        1  07322       4   6  1010145
# 23      P  2019GQ0000259         9        1  07702       4   6  1010145
# 24      P  2019GQ0000274         9        1  01303       4   6  1010145
# 25      P  2019GQ0000278         9        1  01309       4   6  1010145
# 26      P  2019GQ0000289         9        1  05902       4   6  1010145
# 27      P  2019GQ0000333         9        1  08503       4   6  1010145
# 28      P  2019GQ0000336         9        1  03721       4   6  1010145
# 29      P  2019GQ0000338         9        1  07503       4   6  1010145
# ...    ..            ...       ...      ...    ...     ...  ..      ...
# 380061  P  2019HU1412344         9        3  03719       4   6  1010145
# 380062  P  2019HU1412346         9        1  00103       4   6  1010145
# 380063  P  2019HU1412346         9        2  00103       4   6  1010145
# 380064  P  2019HU1412356         9        1  03740       4   6  1010145
# 380065  P  2019HU1412356         9        2  03740       4   6  1010145
# 380066  P  2019HU1412375         9        1  07501       4   6  1010145
# 380067  P  2019HU1412375         9        2  07501       4   6  1010145
# 380068  P  2019HU1412393         9        1  03714       4   6  1010145
# 380069  P  2019HU1412393         9        2  03714       4   6  1010145
# 380070  P  2019HU1412403         9        1  06101       4   6  1010145
# 380071  P  2019HU1412403         9        2  06101       4   6  1010145
# 380072  P  2019HU1412409         9        1  08511       4   6  1010145
# 380073  P  2019HU1412416         9        1  09702       4   6  1010145
# 380074  P  2019HU1412416         9        2  09702       4   6  1010145
# 380075  P  2019HU1412419         9        1  03736       4   6  1010145
# 380076  P  2019HU1412419         9        2  03736       4   6  1010145
# 380077  P  2019HU1412428         9        1  09702       4   6  1010145
# 380078  P  2019HU1412428         9        2  09702       4   6  1010145
# 380079  P  2019HU1412428         9        3  09702       4   6  1010145
# 380080  P  2019HU1412428         9        4  09702       4   6  1010145
# 380081  P  2019HU1412431         9        1  08505       4   6  1010145
# 380082  P  2019HU1412431         9        2  08505       4   6  1010145
# 380083  P  2019HU1412431         9        3  08505       4   6  1010145
# 380084  P  2019HU1412432         9        1  05913       4   6  1010145
# 380085  P  2019HU1412432         9        2  05913       4   6  1010145
# 380086  P  2019HU1412432         9        3  05913       4   6  1010145
# 380087  P  2019HU1412432         9        4  05913       4   6  1010145
# 380088  P  2019HU1412432         9        5  05913       4   6  1010145
# 380089  P  2019HU1412457         9        1  10701       4   6  1010145
# 380090  P  2019HU1412457         9        2  10701       4   6  1010145
#
#         PWGTP  AGEP   ...     PWGTP71  PWGTP72  PWGTP73  PWGTP74  PWGTP75  \
# 0          21    58   ...           0       40        0       20       41
# 1          34    66   ...          62       58       33        7       59
# 2          28    18   ...          27       27       49       49        7
# 3         127    58   ...         117      234      226      135      210
# 4         103    18   ...         180       22      104      104      100
# 5           6    65   ...           0        2        7        7        0
# 6           4    21   ...           0        3        7        0        0
# 7          81    54   ...           7      154       80        7        5
# 8          16    82   ...           0       15        0       16       34
# 9          58    38   ...          57      101       60      104       12
# 10         47    31   ...          10       11       83       84       45
# 11         13    70   ...          22        0        0       13       11
# 12         43    25   ...          79        3       45       84        4
# 13          7    88   ...          10       16        9       16       16
# 14          4    59   ...           8        3        8        6        4
# 15         73    27   ...         133       72        6        6       73
# 16         17    57   ...           4       16       16        3       15
# 17         21    20   ...          41       21        2       43       44
# 18        264    65   ...         277      506      524      542      541
# 19          4    34   ...           7        3        4        4        4
# 20         52    19   ...          89       51       51       92       52
# 21         40    18   ...          69       40        9       39       69
# 22         15    31   ...          26        3       26       15       15
# 23         24    65   ...           0       49       26       27       26
# 24         74    69   ...           6       73      140        6       75
# 25         18    20   ...          19       19       19       19       37
# 26          9    94   ...          19       18        2        9       18
# 27         51    20   ...          49       11       87       90       50
# 28         60    70   ...          59        5       60        5        5
# 29         12    24   ...          11       22       11        3       11
# ...       ...   ...   ...         ...      ...      ...      ...      ...
# 380061    100    25   ...         103       28       27      171      169
# 380062     98    36   ...         101       87       87       87      106
# 380063    110    38   ...         115      104      100       95      108
# 380064    179    60   ...          54      317      183      307      165
# 380065    220    20   ...          66      371      213      337      207
# 380066     93    61   ...          81       91       27       97       29
# 380067     97    66   ...          91       85       25      104       28
# 380068     66    65   ...          68       72       23       67       61
# 380069     81    33   ...          87       83       22       83       70
# 380070    164    74   ...         284       55      135      170      168
# 380071    141    71   ...         237       49      129      154      146
# 380072    146    57   ...         171      232      246       42      136
# 380073    385    77   ...         604      379      352      119      620
# 380074    398    46   ...         705      407      379      139      582
# 380075     66    48   ...          68       63      112      108       69
# 380076     88    68   ...          91       86      143      159       87
# 380077     67    54   ...          85       20      113       98      110
# 380078     85    58   ...          99       26      160      148      141
# 380079    117    30   ...         130       36      205      161      163
# 380080     84     9   ...          99       22      145      138      154
# 380081     54    56   ...          54       15       54       15       51
# 380082     52    54   ...          53       13       49       14       48
# 380083     71    24   ...          67       19       71       21       67
# 380084     51    52   ...          93       49       52       86       15
# 380085     47    47   ...          87       44       46       75       13
# 380086     56    25   ...         108       51       56       96       16
# 380087     55    81   ...         119       53       57       97       17
# 380088     67    94   ...         111       68       67      102       20
# 380089     92    25   ...         153       93      118       61       26
# 380090     55    30   ...          99       64       61       64       21
#
#         PWGTP76  PWGTP77  PWGTP78  PWGTP79  PWGTP80
# 0            40       41       21        0        2
# 1             7       34       34       32       34
# 2            27       27       29        6        5
# 3           217      128      116      125       21
# 4           182       24      103      103       23
# 5            15        8       14       14        6
# 6             4        5        9        3        4
# 7            81       83       83       82       85
# 8            17       33        0       15       31
# 9            13       59       58       56      106
# 10           47       49       47       11       11
# 11           22       23        2       13       22
# 12            2       41       46       77       43
# 13            0        9        0        9        9
# 14            8        3        0        8        6
# 15           73       72       71       72      140
# 16           28       29       26       14        5
# 17            2       21       25        2       42
# 18          264      256      498      536        4
# 19            8        4        4        0        4
# 20           51       91       51       52       51
# 21           39       38       70       40       10
# 22           15       15       14       14       15
# 23            2       24       48       24       25
# 24           74       74       77      145       75
# 25           36       37       21        2       36
# 26            0        2       10        9       10
# 27           50       50       12       52       88
# 28            4        5       64       61       62
# 29           11        3       11       21       20
# ...         ...      ...      ...      ...      ...
# 380061      104       96       95       97      167
# 380062      193      157      141       90       32
# 380063      214      185      162      109       36
# 380064      177      297      190      344      206
# 380065      230      361      220      398      253
# 380066       87      101       23      103       87
# 380067       92       99       26      114       93
# 380068       67       72       18       69       64
# 380069       78       77       22       82       75
# 380070      247      171       44      163      177
# 380071      230      152       37      159      154
# 380072      181      182       42      127      246
# 380073      142      127      401      467      333
# 380074      112      103      367      477      358
# 380075       75      119       66       66       62
# 380076       95      146       92       86       86
# 380077      118       18       80       67       66
# 380078      162       23       93       77       80
# 380079      209       29      118      126       92
# 380080      184       22       77       81       82
# 380081       55       16       54       95       53
# 380082       51       15       51       87       54
# 380083       70       20       67      121       72
# 380084       50       15       15       49       49
# 380085       49       14       16       42       47
# 380086       59       19       17       55       53
# 380087       60       19       15       60       55
# 380088       70       23       20       71       70
# 380089      106       69      141       22       96
# 380090       48       54      109       14       48
#
# [380091 rows x 288 columns]

# %%
print dtdt.now(), 'read file'
NyPums = pd.read_csv('data/csv_pny/psam_p36.csv')
print dtdt.now(), 'format columns'
NyPums.LANP = NyPums.LANP.fillna('bbbb').apply(lambda n: str(n)[:4])
NyPums.POBP = NyPums.POBP.apply(lambda n: '%03d' % n)
NyPums.ANC1P = NyPums.ANC1P.apply(lambda n: '%03d' % n)
NyPums.PUMA = NyPums.PUMA.apply(lambda n: '%05d' % n)
print dtdt.now(), 'done'

NyPums
# Out:
# 2021-08-12 18:48:49.954534 read file

# %%
nycSub = NyPums[NyPums.PUMA.isin(pumasNYC)][['LANP', 'POBP', 'ANC1P', 'PUMA', 'PWGTP']]
laSub = CaPums[CaPums.PUMA.isin(pumasLA)][['LANP', 'POBP', 'ANC1P', 'PUMA', 'PWGTP']]

# %%
laSub.set_index('LANP').join(LanpMapDf).set_index('POBP').join(PobpMapDf).set_index('ANC1P'
                                ).join(AncpMapDf).set_index('PUMA').join(CaPumaMapDf).sort_values('PWGTP', 
                                                                                                  ascending=False).reset_index().to_csv('data/pums_micro_LA.csv', index=False)

# %%
nycSub.set_index('LANP').join(LanpMapDf).set_index('POBP').join(PobpMapDf).set_index('ANC1P'
                                ).join(AncpMapDf).set_index('PUMA').join(NyPumaMapDf).sort_values('PWGTP', 
                                                                                                  ascending=False).reset_index().to_csv('data/pums_micro_NYC.csv', index=False)

# %%
CaPums.groupby('LANP')[['PWGTP']].sum().sort_values('PWGTP', ascending=False).join(LanpMapDf)
# Out:
#          PWGTP                                  language
# LANP
# bbbb  22856501                           N/A (GQ/vacant)
# 1200  10525320                                   Spanish
# 2920    661574                                   Tagalog
# 1970    604235                                   Chinese
# 1960    551489                                Vietnamese
# 2575    372142                                    Korean
# 2050    279079                                 Cantonese
# 2000    265349                                  Mandarin
# 1290    194171                                     Farsi
# 1288    192922                                  Armenian
# 4500    187254                                    Arabic
# 1350    180693                                     Hindi
# 1250    157294                                   Russian
# 1420    143235                                   Punjabi
# 2560    141894                                  Japanese
# 2910    130735                                  Filipino
# 1170    128280                                    French
# 1110     97675                                    German
# 1210     80138                                Portuguese
# 1900     76790                                     Khmer
# 2535     76336                                     Hmong
# 1155     59371                                   Italian
# 1730     56984                                    Telugu
# 1765     54212                                     Tamil
# 1360     53404                                      Urdu
# 1450     48465                                  Gujarati
# 2430     46572                                      Thai
# 4545     42862                                    Hebrew
# 2475     33756                                       Lao
# 2030     32995                           Min Nan Chinese
# ...        ...                                       ...
# 6500      1437               Other Niger-Congo languages
# 1242      1340                                  Albanian
# 1525      1195                           Pakistan N.E.C.
# 4900      1161                    Nilo-Saharan languages
# 7060      1118                     Uto-Aztecan languages
# 4830      1079                                     Oromo
# 1283       885                                   Latvian
# 6300       823                           Edoid languages
# 6230       744                             Gbe languages
# 5525       693                                     Shona
# 1274       679                                Macedonian
# 6839       672                                    Ojibwa
# 6205       636                                        Ga
# 6936       486  Kiowa-Tanoan languages (2016 or earlier)
# 3350       468                                  Chuukese
# 5845       400                         Manding languages
# 5900       383                     Other Mande languages
# 7032       381                       Muskogean languages
# 1069       307                              Kabuverdianu
# 7050       299                                  Cherokee
# 6800       289                           Aleut languages
# 7019       279                          Dakota languages
# 5940       220                                     Fulah
# 7039       181                                     Keres
# 5950       170                                     Wolof
# 2270       164                            Chin languages
# 1175       111                              Cajun French
# 7059        59                    Zuni (2016 or earlier)
# 6930        58                          Apache languages
# 1125        24                       Pennsylvania German
#
# [133 rows x 2 columns]

# %%
CaPums.groupby('POBP')[['PWGTP']].sum().sort_values('PWGTP', ascending=False).join(PobpMapDf)
# Out:
#          PWGTP                        birthplace
# POBP
# 006   21468960                     California/CA
# 303    4306098                            Mexico
# 233     884983                       Philippines
# 207     624326                             China
# 036     615544                       New York/NY
# 247     529559                           Vietnam
# 048     481798                          Texas/TX
# 210     474849                             India
# 017     453858                       Illinois/IL
# 312     437385                       El Salvador
# 217     338128                             Korea
# 039     280204                           Ohio/OH
# 026     278827                       Michigan/MI
# 042     276129                   Pennsylvania/PA
# 313     275903                         Guatemala
# 053     238330                     Washington/WA
# 212     215586                              Iran
# 004     199733                        Arizona/AZ
# 034     197682                     New Jersey/NJ
# 025     190930                  Massachusetts/MA
# 240     179052                            Taiwan
# 008     169731                       Colorado/CO
# 041     165525                         Oregon/OR
# 029     151779                       Missouri/MO
# 012     149740                        Florida/FL
# 301     147492                            Canada
# 027     143124                      Minnesota/MN
# 215     141069                             Japan
# 018     135745                        Indiana/IN
# 040     135666                       Oklahoma/OK
# ...        ...                               ...
# 464       1177    Northern Africa, Not Specified
# 228       1145          Mongolia (2017 or later)
# 512       1126                        Micronesia
# 324       1065                          Barbados
# 100        961                           Albania
# 208        903          Cyprus (2016 or earlier)
# 323        801                           Bahamas
# 343        766                       West Indies
# 152        764                         Macedonia
# 444        741                           Senegal
# 142        646  Northern Ireland (2017 or later)
# 219        627        Kyrgyzstan (2017 or later)
# 166        536            Europe (2017 or later)
# 330        525                           Grenada
# 340        501      St. Vincent & the Grenadines
# 321        456                 Antigua & Barbuda
# 339        424                         St. Lucia
# 456        407           Tunisia (2017 or later)
# 454        378                              Togo
# 328        339                          Dominica
# 408        331                        Cabo Verde
# 425        284       Ivory Coast (2017 or later)
# 168        243                        Montenegro
# 420        238                            Gambia
# 203        222                            Bhutan
# 423         75                            Guinea
# 463         36       South Sudan (2017 or later)
# 338         15   St. Kitts-Nevis (2017 or later)
# 167         14            Kosovo (2017 or later)
# 442         13            Rwanda (2017 or later)
#
# [225 rows x 2 columns]

# %%
CaPums.groupby('ANC1P')[['PWGTP']].sum().sort_values('PWGTP', ascending=False).join(AncpMapDf)
# Out:
#          PWGTP                    ancestry
# ANC1P
# 210    8311824                     Mexican
# 999    4285350                Not reported
# 032    1916228                      German
# 902    1465658            African American
# 050    1458112                       Irish
# 211    1405198            Mexican American
# 022    1346902                     English
# 706    1314693                     Chinese
# 924    1254234                       White
# 720    1205589                    Filipino
# 051    1068545                     Italian
# 939     883503                    American
# 290     812128                    Hispanic
# 615     602542                Asian Indian
# 226     582464                  Salvadoran
# 785     574086                  Vietnamese
# 195     505043                    European
# 750     459473                      Korean
# 222     356355                  Guatemalan
# 026     354698                      French
# 740     334144                    Japanese
# 903     306380                       Black
# 088     306093                    Scottish
# 148     296127                     Russian
# 142     294080                      Polish
# 291     284581                     Spanish
# 082     243990                   Norwegian
# 084     240871                  Portuguese
# 431     237409                    Armenian
# 089     236361                     Swedish
# ...        ...                         ...
# 598       1088             Western African
# 566       1030              Sierra Leonean
# 359       1009           Other West Indian
# 310        967           Dutch West Indian
# 820        901                 Micronesian
# 236        901                  Paraguayan
# 009        808                     Flemish
# 922        660                      Eskimo
# 564        639                  Senegalese
# 001        556                    Alsatian
# 131        529                 Montenegrin
# 300        448                    Bahamian
# 124        406                         Rom
# 331        404           St Lucia Islander
# 329        352                   Grenadian
# 423        347     Kuwaiti (2017 or later)
# 927        335                 Appalachian
# 179        332                   Slavonian
# 322        299         British West Indian
# 921        293     Aleut (2016 or earlier)
# 824        245     Palauan (2017 or later)
# 325        244         Antigua and Barbuda
# 330        203  Vincent-Grenadine Islander
# 970        183  New Mexico (2017 or later)
# 404        155      Libyan (2017 or later)
# 607        154                   Bhutanese
# 593        136  Zimbabwean (2017 or later)
# 586         52        Togo (2017 or later)
# 936         50     Acadian (2017 or later)
# 527         50     Gambian (2017 or later)
#
# [240 rows x 2 columns]

# %%
CaPums.groupby('PUMA')[['PWGTP']].sum().sort_values('PWGTP', ascending=False).join(CaPumaMapDf)
# Out:
#         PWGTP                                               name
# PUMA
# 05904  235455     Orange County (Central)--Irvine City (Central)
# 00110  229118  Alameda County (East)--Livermore, Pleasanton &...
# 02902  216503     Kern County (Central)--Bakersfield City (West)
# 07703  216196  San Joaquin County (South)--Tracy, Manteca & L...
# 05905  213206  Orange County (Northeast)--Lake Forest, Irvine...
# 11300  212251  Yolo County--Davis, Woodland & West Sacramento...
# 08303  209226           Santa Barbara County--South Coast Region
# 05903  208559  Orange County (West Central)--Newport Beach, A...
# 08501  207446  Santa Clara County (Northwest)--Mountain View,...
# 03729  206730  Los Angeles County (West Central)--LA City (We...
# 03734  205369  Los Angeles County--LA City (East Central/Silv...
# 00109  204011  Alameda County (South Central)--Fremont City (...
# 07301  201698  San Diego County (Northwest)--Oceanside City &...
# 06505  201227  Riverside County (Southwest)--Menifee, Lake El...
# 11103  200420  Ventura County (Southwest)--Oxnard & Port Huen...
# 03735  199814  Los Angeles County--LA City (Mount Washington,...
# 05910  199186  Orange County (North Central)--Anaheim City (E...
# 05914  198695   Orange County (Northwest)--Huntington Beach City
# 03719  198507        Los Angeles County (Central)--Glendale City
# 02901  197210  Kern County (West)--Delano, Wasco & Shafter Ci...
# 03702  195266  Los Angeles County (Northwest)--Santa Clarita ...
# 05907  194817  Orange County (North Central)--Fullerton & Pla...
# 03717  193613  Los Angeles County (East Central)--Arcadia, Sa...
# 06508  192142   Riverside County (Northwest)--Moreno Valley City
# 09703  191647           Sonoma County (Central)--Santa Rosa City
# 02905  190419  Kern County (East)--Ridgecrest, Arvin, Tehacha...
# 00300  187495  Alpine, Amador, Calaveras, Inyo, Mariposa, Mon...
# 07701  187342  San Joaquin County (Central)--Stockton City (N...
# 03748  186852  Los Angeles County--LA (Southwest/Marina del R...
# 05906  186600  Orange County (North)--Yorba Linda, La Habra &...
# ...       ...                                                ...
# 03768  112302  Los Angeles County (Southwest)--Palos Verdes P...
# 03714  112264  Los Angeles County--Diamond Bar, La Habra Heig...
# 03713  112236  Los Angeles County (East Central)--Covina & Wa...
# 06712  112233  Sacramento County (Northeast)--Folsom City, Or...
# 03731  112010  Los Angeles County (Central)--West Hollywood &...
# 03753  111951            Los Angeles County (South)--Downey City
# 07502  111936  San Francisco County (North & East)--North Bea...
# 02904  111630  Kern County (Central)--Bakersfield City (South...
# 06705  111321  Sacramento County (Northwest)--Sacramento City...
# 04101  110441  Marin County (North & West)--Novato & San Rafa...
# 09904  110211   Stanislaus County (Central)--Modesto City (East)
# 08511  110149  Santa Clara County (Central)--San Jose City (S...
# 05902  109894  Orange County (South Central)--Mission Viejo &...
# 08103  109798  San Mateo County (Central)--San Mateo (North),...
# 08514  109694  Santa Clara County (Central)--San Jose City (E...
# 08512  109568  Santa Clara County (Central)--San Jose City (S...
# 06701  109409  Sacramento County (North Central)--Citrus Heig...
# 00702  109300  Butte County (Southeast)--Oroville City & Para...
# 04701  108776  Merced County (West & South)--Los Banos & Livi...
# 05915  108404  Orange County (Southeast)--Rancho Santa Margar...
# 07902  108309       San Luis Obispo County (East)--Inland Region
# 07110  108052  San Bernardino County (Southwest)--Fontana Cit...
# 07106  106294  San Bernardino County (Southwest)--Colton, Lom...
# 01903  106261  Fresno County (Central)--Fresno City (East Cen...
# 03766  105195  Los Angeles County (South)--Long Beach City (S...
# 08302  104992  Santa Barbara County (North)--Lompoc, Guadalup...
# 03728  104311  Los Angeles County (Southwest)--Santa Monica City
# 03726  103097  Los Angeles County--Calabasas, Agoura Hills, M...
# 05700  101772                           Nevada & Sierra Counties
# 03769  100531  Los Angeles County (Southeast)--Long Beach (Ce...
#
# [265 rows x 2 columns]
